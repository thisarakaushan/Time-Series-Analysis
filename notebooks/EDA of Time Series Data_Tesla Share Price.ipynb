# %% [markdown]
# pip install pandas-datareader

# %% [markdown]
# pip install yfinance

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
import yfinance as yf

# fetch data for TSLA(tesla)
df = yf.download('TSLA')
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-07-05  278.820007  283.850006  277.600006  282.480011  282.480011
# 2023-07-06  278.089996  279.970001  272.880005  276.540009  276.540009
# 2023-07-07  278.429993  280.779999  273.769989  274.429993  274.429993
# 2023-07-10  276.470001  277.519989  265.100006  269.609985  269.609985
# 2023-07-11  268.649994  270.899994  266.369995  269.790009  269.790009
#
#                Volume
# Date
# ...

# %% [markdown]
# * pdr.get_data_yahoo('TSLA') # TypeError: string indices must be integers

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-07-05  278.820007  283.850006  277.600006  282.480011  282.480011
# 2023-07-06  278.089996  279.970001  272.880005  276.540009  276.540009
# 2023-07-07  278.429993  280.779999  273.769989  274.429993  274.429993
# 2023-07-10  276.470001  277.519989  265.100006  269.609985  269.609985
# 2023-07-11  268.649994  270.899994  266.369995  269.790009  269.790009
#
#                Volume
# Date
# 2023-07-05  131530900
# 2023-07-06  120332100
# 2023-07-07  113602000
# 2023-07-10  119425400
# 2023-07-11   91773500

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['High'].plot(figsize=(12, 4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# give x limit and y limit

df['High'].plot(xlim=['2020-01-01', '2021-09-01'], figsize=(12, 4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['High'].plot(xlim=['2020-01-01', '2021-09-01'], ylim=[0, 300], figsize=(12, 4), color='red')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2023-06-27', '2023-06-28', '2023-06-29', '2023-06-30',
#                '2023-07-03', '2023-07-05', '2023-07-06', '2023-07-07',
#                '2023-07-10', '2023-07-11'],
#               dtype='datetime64[ns]', name='Date', length=3280, freq=None)

# %%
df.loc['2020-01-01':'2021-09-01']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ...                ...         ...         ...         ...         ...
# 2021-08-26  236.103333  238.466660  232.539993  233.720001  233.720001
# 2021-08-27  235.000000  238.333328  234.033340  237.306671  237.306671
# 2021-08-30  238.240005  243.666672  237.576660  243.636673  243.636673
# 2021-08-31  244.333328  246.796661  242.146667  245.240005  245.240005
# 2021-09-01  244.693329  247.330002  243.756668  244.696671  244.696671
#
#                Volume
# Date
# 2020-01-02  142981500
# 2020-01-03  266677500
# 2020-01-06  151995000
# ...

# %%
df.loc['2020-01-01':'2021-09-01'].index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
share_open = df.loc['2020-01-01':'2021-09-01']['Open']
share_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2021-08-26    236.103333
# 2021-08-27    235.000000
# 2021-08-30    238.240005
# 2021-08-31    244.333328
# 2021-09-01    244.693329
# Name: Open, Length: 421, dtype: float64

# %%
index = df.loc['2020-01-01':'2021-09-01'].index

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure, axis = plt.subplots()
plt.tight_layout()
figure.autofmt_xdate() # preventing overlapping
axis.plot(index, share_open)

# %%
# datetime index

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3280 entries, 2010-06-29 to 2023-07-11
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3280 non-null   float64
#  1   High       3280 non-null   float64
#  2   Low        3280 non-null   float64
#  3   Close      3280 non-null   float64
#  4   Adj Close  3280 non-null   float64
#  5   Volume     3280 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 308.4 KB

# %%
df = df.reset_index() # if you can set it using df.set_index(df['Date'])
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3275 2023-07-05  278.820007  283.850006  277.600006  282.480011  282.480011
# 3276 2023-07-06  278.089996  279.970001  272.880005  276.540009  276.540009
# 3277 2023-07-07  278.429993  280.779999  273.769989  274.429993  274.429993
# 3278 2023-07-10  276.470001  277.519989  265.100006  269.609985  269.609985
# 3279 2023-07-11  268.649994  270.899994  266.369995  269.790009  269.790009
#
#          Volume
# 0     281494500
# 1     257806500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3280 entries, 0 to 3279
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3280 non-null   datetime64[ns]
#  1   Open       3280 non-null   float64
#  2   High       3280 non-null   float64
#  3   Low        3280 non-null   float64
#  4   Close      3280 non-null   float64
#  5   Adj Close  3280 non-null   float64
#  6   Volume     3280 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 179.5 KB

# %% [markdown]
# * if datetime is not in this format 'datetime64[ns]', we want to covert that datetime column into the format using pd.to_datetime(df['Date'])

# %%
df = df.set_index('Date', drop=True)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-07-05  278.820007  283.850006  277.600006  282.480011  282.480011
# 2023-07-06  278.089996  279.970001  272.880005  276.540009  276.540009
# 2023-07-07  278.429993  280.779999  273.769989  274.429993  274.429993
# 2023-07-10  276.470001  277.519989  265.100006  269.609985  269.609985
# 2023-07-11  268.649994  270.899994  266.369995  269.790009  269.790009
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
datetime(2021, 12, 11)
# Out:
# datetime.datetime(2021, 12, 11, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 7, 12, 9, 32, 14, 417097)

# %% [markdown]
# ### Time Resampling

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
# rule = 'A' means year end frequency(means the end of the year data you are basically going to start)

df.resample(rule='A')

# %%
df.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
df.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
type(df.resample(rule='A').max())
# Out:
# pandas.core.frame.DataFrame

# %%
df.resample(rule='A').max()['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# quaterly start frequency

df.resample(rule='QS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-01    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-01    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-01    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-01    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-01    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %% [markdown]
#  [Click here to visit the article](https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78)

# %%
# business end frequency

df.resample(rule='BA').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-30    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-30   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-29   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
# business quaterly end frequency

df.resample(rule='BQS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-03    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-03    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-02    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-02    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-02    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %%
df['Open'].resample(rule='A').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# getting monthlt mean

df['Open'].resample(rule='M').mean()
# Out:
# Date
# 2010-06-30      1.493000
# 2010-07-31      1.338222
# 2010-08-31      1.303030
# 2010-09-30      1.385270
# 2010-10-31      1.381556
#                  ...
# 2023-03-31    188.425218
# 2023-04-30    177.734212
# 2023-05-31    174.773182
# 2023-06-30    244.059050
# 2023-07-31    276.158330
# Freq: M, Name: Open, Length: 158, dtype: float64

# %%
df['Open'].resample(rule='M').mean().plot(kind='bar', figsize=(30,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Rolling and expanding

# %%
df['High'].rolling(10)
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
df['High'].rolling(10).mean()
# Out:
# Date
# 2010-06-29           NaN
# 2010-06-30           NaN
# 2010-07-01           NaN
# 2010-07-02           NaN
# 2010-07-06           NaN
#                  ...
# 2023-07-05    266.637001
# 2023-07-06    266.935002
# 2023-07-07    268.513002
# 2023-07-10    270.020000
# 2023-07-11    271.273000
# Name: High, Length: 3280, dtype: float64

# %%
df['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# 2010-07-07         NaN
# 2010-07-08         NaN
# 2010-07-09         NaN
# 2010-07-12         NaN
# 2010-07-13    1.421333
# 2010-07-14    1.389000
# 2010-07-15    1.329533
# 2010-07-16    1.298733
# 2010-07-19    1.293067
# 2010-07-20    1.305400
# 2010-07-21    1.333867
# 2010-07-22    1.358733
# 2010-07-23    1.383133
# 2010-07-26    1.406000
# 2010-07-27    1.422933
# Name: High, dtype: float64

# %%
df['Open: 30 days rolling'] = df['Open'].rolling(30).mean()

# %%
df.head(32)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# 2010-07-15  1.329333  1.433333  1.266667  1.326000   1.326000   56097000
# ...

# %%
df[['Open', 'Open: 30 days rolling']].plot(figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# * the orange line is the smoothened version of the zigzag(blue) line data

# %% [markdown]
# ## [Simple Moving Average](https://www.investopedia.com/terms/s/sma.asp)

# %%
df['Open'].plot(figsize=(12, 4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Open:10 days rolling'] = df['Open'].rolling(window=10, min_periods=1).mean()

# %%
df[['Open', 'Open:10 days rolling']].plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[['Open', 'Open:10 days rolling']].plot(xlim=['2020-01-01', '2021-01-01'], figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Open:30 days rolling'] = df['Open'].rolling(window=30, min_periods=1).mean()
df['Open:50 days rolling'] = df['Open'].rolling(window=50, min_periods=1).mean()

# %%
df[['Open', 'Open:10 days rolling', 'Open:30 days rolling', 'Open:50 days rolling']].plot(xlim=['2020-01-01', '2021-01-01'], figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# * But there is a disadvantage in Simple Moving Average:
#     - we give similar importance to all the data but time series data give more weight to the Recent Data.

# %% [markdown]
# ## [Cummulative Moving Average](https://www.automateexcel.com/stats/cumulative-rolling-average/)

# %%
# Using Expanding Function

df['Open'].expanding().mean().plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## [Exponential Moving Average](https://www.investopedia.com/terms/e/ema.asp)

# %%
# EMA = ((close value - previous EMA) * multiplier) + previous EMA, also multiplier = (2/(rolling window size + 1))

# smoothing factor = 0.1
df['EMA_0.1'] = df['Open'].ewm(alpha=0.1, adjust=False).mean()

# %%
df[['Open', 'EMA_0.1']].plot(xlim=['2020-01-01', '2021-01-01'], figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# * Without any lag we can able to see the entire Exponential Moving Average
#
# * Advantage - removing lags and we are also trying to find out the exponential moving average which is pretty much better than                 the Simple Moving Average.

# %%
# changing smoothing factor = 0.3

df['EMA_0.3'] = df['Open'].ewm(alpha=0.3, adjust=False).mean()

# %%
df[['Open', 'EMA_0.1', 'EMA_0.3']].plot(xlim=['2020-01-01', '2021-01-01'], figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['EMA_5days'] = df['Open'].ewm(span=5).mean()

# %%
df[['Open', 'EMA_0.1', 'EMA_5days']].plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>
